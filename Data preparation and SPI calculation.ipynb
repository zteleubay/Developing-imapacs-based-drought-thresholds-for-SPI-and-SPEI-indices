# %% [markdown]
# Create NetCDF from monthly precipitation data

# %%
import os
import numpy as np
import rasterio
from netCDF4 import Dataset, date2num
from datetime import datetime, timedelta

# Define file pattern and date range for monthly data
file_pattern = 'PRISM_ppt_stable_4kmM3_{}_bil.bil'
start_date = datetime(1981, 1, 1)
end_date = datetime(2022, 12, 1)  # End date set to December 2020

# Define the extent and resolution
extent = (-125.0208333333335, 24.0625, -66.4791666661985, 49.9375)
lon_start, lat_start, lon_end, lat_end = extent
lon_res = 0.04166666666667  # 4km resolution in degrees
lat_res = 0.04166666666667

# Generate latitude and longitude arrays based on the actual data dimensions
nlat, nlon = 621, 1405  # Actual dimensions from the sample data
lon = np.linspace(lon_start, lon_end, nlon)
lat = np.linspace(lat_end, lat_start, nlat)

# Create the NetCDF file
output_file = 'PRISM_monthly_precipitation_1981_2022.nc'
if os.path.exists(output_file):
    os.remove(output_file)

nco = Dataset(output_file, 'w', format='NETCDF4')

# Create dimensions
nco.createDimension('lat', nlat)
nco.createDimension('lon', nlon)
nco.createDimension('time', None)

# Create variables
lato = nco.createVariable('lat', 'f4', ('lat',))
lono = nco.createVariable('lon', 'f4', ('lon',))
timeo = nco.createVariable('time', 'f4', ('time',))
preco = nco.createVariable('precipitation', 'f4', ('time', 'lat', 'lon',), fill_value=np.nan)  # Set fill value to NaN

# Set variable attributes
timeo.units = 'days since 1858-11-17 00:00:00'
timeo.calendar = 'gregorian'
timeo.standard_name = 'time'
lato.units = 'degrees_north'
lato.standard_name = 'latitude'
lono.units = 'degrees_east'
lono.standard_name = 'longitude'
preco.units = 'mm/month'
preco.standard_name = 'monthly precipitation'

# Assign coordinate variables
lato[:] = lat
lono[:] = lon

# Initialize time array
months = []
current_month = start_date
while current_month <= end_date:
    months.append(current_month)
    current_month = (current_month.replace(day=28) + timedelta(days=4)).replace(day=1)  # Move to the first day of the next month

total_months = len(months)
time_values = date2num(months, units=timeo.units, calendar=timeo.calendar)
timeo[:] = time_values

# Read and assign precipitation data
for month, current_month in enumerate(months):
    file_name = file_pattern.format(current_month.strftime('%Y%m'))
    try:
        with rasterio.open(file_name) as src:
            data = src.read(1).astype(np.float32)  # Ensure data is in float32 format to handle NaNs
            if data.shape != (nlat, nlon):
                raise ValueError(f"Data shape mismatch: {data.shape} vs {(nlat, nlon)}")
            preco[month, :, :] = data
    except FileNotFoundError:
        print(f"File not found: {file_name}, filling with NaNs")
        preco[month, :, :] = np.nan
    except ValueError as e:
        print(f"Error with file {file_name}: {e}")
        preco[month, :, :] = np.nan
    if month % 12 == 0:
        print(f"Processed {month}/{total_months} months")

# Close the NetCDF file
nco.close()

print(f"NetCDF file created: {output_file}")
# Out:
# Processed 0/504 months
# Processed 12/504 months
# Processed 24/504 months
# Processed 36/504 months
# Processed 48/504 months
# Processed 60/504 months
# Processed 72/504 months
# Processed 84/504 months
# Processed 96/504 months
# Processed 108/504 months
# Processed 120/504 months
# Processed 132/504 months
# Processed 144/504 months
# Processed 156/504 months
# Processed 168/504 months
# Processed 180/504 months
# Processed 192/504 months
# Processed 204/504 months
# Processed 216/504 months
# Processed 228/504 months
# Processed 240/504 months
# Processed 252/504 months
# Processed 264/504 months
# Processed 276/504 months
# Processed 288/504 months
# Processed 300/504 months
# Processed 312/504 months
# Processed 324/504 months
# Processed 336/504 months
# Processed 348/504 months
# Processed 360/504 months
# Processed 372/504 months
# Processed 384/504 months
# Processed 396/504 months
# Processed 408/504 months
# Processed 420/504 months
# Processed 432/504 months
# Processed 444/504 months
# Processed 456/504 months
# Processed 468/504 months
# Processed 480/504 months
# Processed 492/504 months
# NetCDF file created: PRISM_monthly_precipitation_1981_2022.nc

# %%
import xarray as xr

def inspect_data(file_path):
    try:
        ds = xr.open_dataset(file_path)
        print("Dataset loaded successfully.")
        print(ds)
        print(ds.variables)
    except Exception as e:
        print(f"Error loading dataset: {e}")

file_path = 'PRISM_monthly_precipitation_1981_2022.nc'
inspect_data(file_path)
# Out:
# Dataset loaded successfully.
# <xarray.Dataset>
# Dimensions:        (lat: 621, lon: 1405, time: 504)
# Coordinates:
#   * lat            (lat) float32 49.94 49.9 49.85 49.81 ... 24.15 24.1 24.06
#   * lon            (lon) float32 -125.0 -125.0 -124.9 ... -66.56 -66.52 -66.48
#   * time           (time) datetime64[ns] 1981-01-01 1981-02-01 ... 2022-12-01
# Data variables:
#     precipitation  (time, lat, lon) float32 ...
# Frozen({'lat': <xarray.IndexVariable 'lat' (lat: 621)>
# array([49.9375  , 49.895767, 49.85403 , ..., 24.145967, 24.104235, 24.0625  ],
#       dtype=float32)
# Attributes:
#     units:          degrees_north
#     standard_name:  latitude, 'lon': <xarray.IndexVariable 'lon' (lon: 1405)>
# array([-125.020836, -124.97913 , -124.93744 , ...,  -66.56256 ,  -66.52087 ,
#         -66.479164], dtype=float32)
# Attributes:
#     units:          degrees_east
#     standard_name:  longitude, 'time': <xarray.IndexVariable 'time' (time: 504)>
# array(['1981-01-01T00:00:00.000000000', '1981-02-01T00:00:00.000000000',
#        '1981-03-01T00:00:00.000000000', ..., '2022-10-01T00:00:00.000000000',
#        '2022-11-01T00:00:00.000000000', '2022-12-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Attributes:
#     standard_name:  time, 'precipitation': <xarray.Variable (time: 504, lat: 621, lon: 1405)>
# [439742520 values with dtype=float32]
# Attributes:
#     units:          mm/month
#     standard_name:  monthly precipitation})

# %% [markdown]
# Calculate SPI-3 from the precipitation NetCDF

# %%
import xarray as xr
import numpy as np
from scipy import stats as st
import rasterio
from rasterio.transform import from_origin
import os
import pandas as pd  # Import pandas for datetime conversion

# Load the PRISM dataset
da_data = xr.open_dataset('PRISM_monthly_precipitation_1981_2022.nc')

# Select the precipitation data
ds_RR = da_data['precipitation']

# Standardized Precipitation Index Function
def spi(ds, thresh):
    # Rolling Mean / Moving Averages
    ds_ma = ds.rolling(time=thresh, center=False).mean()
    
    # Natural log of moving averages, handling zeros and negative values
    ds_ma = ds_ma.where(ds_ma > 0)
    ds_In = np.log(ds_ma)
    
    # Overall Mean of Moving Averages
    ds_mu = ds_ma.mean('time')
    
    # Summation of Natural log of moving averages
    ds_sum = ds_In.sum('time')
    
    # Computing essentials for gamma distribution
    n = ds_In[thresh-1:, :, :].count('time')  # Size of data
    A = np.log(ds_mu) - (ds_sum / n)             # Computing A
    alpha = (1 / (4 * A)) * (1 + (1 + (4 * A / 3))**0.5)  # Computing alpha (a)
    beta = ds_mu / alpha                         # Computing beta (scale)
    
    # Gamma Distribution (CDF)
    gamma_func = lambda data, a, scale: st.gamma.cdf(data, a=a, scale=scale)
    gamma = xr.apply_ufunc(gamma_func, ds_ma, alpha, beta)
    
    # Standardized Precipitation Index (Inverse of CDF)
    norminv = lambda data: st.norm.ppf(data, loc=0, scale=1)
    norm_spi = xr.apply_ufunc(norminv, gamma)  # loc is mean and scale is standard dev.
    
    return norm_spi

# Apply the SPI function with a 3-month scale
i = 3
spi_result = spi(ds_RR, i)

# Create a directory to save GeoTIFF files
output_dir = 'spi_tiffs'
os.makedirs(output_dir, exist_ok=True)

# Loop over each time step and save SPI as GeoTIFF with band names
for idx, timestamp in enumerate(spi_result.time.values):
    # Convert numpy.datetime64 to datetime
    timestamp = pd.to_datetime(str(timestamp))
    
    # Form the filename
    filename = os.path.join(output_dir, f"spi_{timestamp.strftime('%Y%m')}.tif")
    
    # Extract the SPI value for this time step
    spi_slice = spi_result.isel(time=idx)
    
    # Get data as numpy array
    spi_array = spi_slice.values
    
    # Get spatial information
    transform = from_origin(ds_RR.lon.values[0], ds_RR.lat.values[0], 
                            ds_RR.lon.values[1] - ds_RR.lon.values[0], 
                            ds_RR.lat.values[1] - ds_RR.lat.values[0])
    height, width = spi_array.shape
    
    # Write to GeoTIFF with CRS WGS84
    with rasterio.open(filename, 'w', driver='GTiff', 
                       width=width, height=height, count=1, 
                       dtype=spi_array.dtype, 
                       crs='EPSG:4326', transform=transform) as dst:
        dst.write(spi_array, 1)
        
    # Set band name
    with rasterio.open(filename, 'r+', driver='GTiff') as dst:
        dst.update_tags(b1=dict(NAME=f'SPI_{timestamp.strftime("%Y-%m")}'))

print("GeoTIFF files saved successfully.")
# Out:
# GeoTIFF files saved successfully.

# %%
#SPI-3 calculation using the Cumulative 3 month precipitation

import xarray as xr
import numpy as np
from scipy import stats as st
import rasterio
from rasterio.transform import from_origin
import os
import pandas as pd  # Import pandas for datetime conversion

# Load the PRISM dataset
da_data = xr.open_dataset('PRISM_monthly_precipitation_1981_2022.nc')

# Select the precipitation data
ds_RR = da_data['precipitation']

# Standardized Precipitation Index Function with Cumulative Precipitation
def spi(ds, thresh):
    # Cumulative Precipitation
    ds_cp = ds.rolling(time=thresh, center=False).sum()  # Cumulative precipitation over the threshold

    # Natural log of cumulative precipitation, handling zeros
    ds_cp = ds_cp.where(ds_cp > 0)
    ds_In = np.log(ds_cp)

    # Overall Mean of Cumulative Precipitation
    ds_mu = ds_cp.mean('time')

    # Summation of Natural log of cumulative precipitation
    ds_sum = ds_In.sum('time')

    # Computing essentials for gamma distribution
    n = ds_In[thresh-1:, :, :].count('time')  # Size of data
    A = np.log(ds_mu) - (ds_sum / n)  # Computing A
    alpha = (1 / (4 * A)) * (1 + (1 + (4 * A / 3))**0.5)  # Computing alpha (a)
    beta = ds_mu / alpha  # Computing beta (scale)

    # Gamma Distribution (CDF)
    gamma_func = lambda data, a, scale: st.gamma.cdf(data, a=a, scale=scale)
    gamma = xr.apply_ufunc(gamma_func, ds_cp, alpha, beta)

    # Standardized Precipitation Index (Inverse of CDF)
    norminv = lambda data: st.norm.ppf(data, loc=0, scale=1)
    norm_spi = xr.apply_ufunc(norminv, gamma)  # loc is mean and scale is standard dev.

    return norm_spi

# Apply the SPI function with a 3-month scale
i = 3
spi_result = spi(ds_RR, i)

# Create a directory to save GeoTIFF files
output_dir = 'spi_tiffs'
os.makedirs(output_dir, exist_ok=True)

# Loop over each time step and save SPI as GeoTIFF with band names
for idx, timestamp in enumerate(spi_result.time.values):
    # Convert numpy.datetime64 to datetime
    timestamp = pd.to_datetime(str(timestamp))
    
    # Form the filename
    filename = os.path.join(output_dir, f"spi_{timestamp.strftime('%Y%m')}.tif")
    
    # Extract the SPI value for this time step
    spi_slice = spi_result.isel(time=idx)
    
    # Get data as numpy array
    spi_array = spi_slice.values
    
    # Get spatial information
    transform = from_origin(ds_RR.lon.values[0], ds_RR.lat.values[0], 
                            ds_RR.lon.values[1] - ds_RR.lon.values[0], 
                            ds_RR.lat.values[1] - ds_RR.lat.values[0])
    height, width = spi_array.shape
    
    # Write to GeoTIFF with CRS WGS84
    with rasterio.open(filename, 'w', driver='GTiff', 
                       width=width, height=height, count=1, 
                       dtype=spi_array.dtype, 
                       crs='EPSG:4326', transform=transform) as dst:
        dst.write(spi_array, 1)
        
    # Set band name
    with rasterio.open(filename, 'r+', driver='GTiff') as dst:
        dst.update_tags(b1=dict(NAME=f'SPI_{timestamp.strftime("%Y-%m")}'))

print("GeoTIFF files saved successfully.")

# %%
#Check if the time resolution is months

import xarray as xr

# Load the PRISM dataset
da_data = xr.open_dataset('PRISM_monthly_precipitation_1981_2022.nc')

# Print the time values to verify the resolution
print(da_data['time'])
# Out:
# <xarray.DataArray 'time' (time: 504)>
# array(['1981-01-01T00:00:00.000000000', '1981-02-01T00:00:00.000000000',
#        '1981-03-01T00:00:00.000000000', ..., '2022-10-01T00:00:00.000000000',
#        '2022-11-01T00:00:00.000000000', '2022-12-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 1981-01-01 1981-02-01 ... 2022-12-01
# Attributes:
#     standard_name:  time
# No units assigned to the time dimension.

# %% [markdown]
# Flip and move the raster

# %%
import os
import rasterio
import numpy as np

# Define input and output directories
input_folder = 'spi_tiffs_raw'
output_folder = 'spi_tiffs_final'

# Make sure the output directory exists
os.makedirs(output_folder, exist_ok=True)

# Iterate over all files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith('.tif'):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)
        
        # Open the input .tif file
        with rasterio.open(input_path) as src:
            # Read the single band data
            data = src.read(1)  # Read the first band only
            
            # Flip the data vertically (north to south)
            flipped_data = np.flipud(data)
            
            # Update the metadata for the output file
            metadata = src.meta.copy()
            
            # Write the flipped data to a new .tif file
            with rasterio.open(output_path, 'w', **metadata) as dst:
                dst.write(flipped_data, 1)  # Write to the first band

        print(f"Flipped {filename} and saved to {output_path}")
# Out:
# Flipped spi_200504.tif and saved to spi_tiffs_final/spi_200504.tif
# Flipped spi_200510.tif and saved to spi_tiffs_final/spi_200510.tif
# Flipped spi_199809.tif and saved to spi_tiffs_final/spi_199809.tif
# Flipped spi_201801.tif and saved to spi_tiffs_final/spi_201801.tif
# Flipped spi_199612.tif and saved to spi_tiffs_final/spi_199612.tif
# Flipped spi_199606.tif and saved to spi_tiffs_final/spi_199606.tif
# Flipped spi_202111.tif and saved to spi_tiffs_final/spi_202111.tif
# Flipped spi_200706.tif and saved to spi_tiffs_final/spi_200706.tif
# Flipped spi_200712.tif and saved to spi_tiffs_final/spi_200712.tif
# Flipped spi_202105.tif and saved to spi_tiffs_final/spi_202105.tif
# Flipped spi_198901.tif and saved to spi_tiffs_final/spi_198901.tif
# Flipped spi_200909.tif and saved to spi_tiffs_final/spi_200909.tif
# Flipped spi_199410.tif and saved to spi_tiffs_final/spi_199410.tif
# Flipped spi_199404.tif and saved to spi_tiffs_final/spi_199404.tif
# Flipped spi_199202.tif and saved to spi_tiffs_final/spi_199202.tif
# Flipped spi_201008.tif and saved to spi_tiffs_final/spi_201008.tif
# Flipped spi_200302.tif and saved to spi_tiffs_final/spi_200302.tif
# Flipped spi_199001.tif and saved to spi_tiffs_final/spi_199001.tif
# Flipped spi_200303.tif and saved to spi_tiffs_final/spi_200303.tif
# Flipped spi_201009.tif and saved to spi_tiffs_final/spi_201009.tif
# Flipped spi_199203.tif and saved to spi_tiffs_final/spi_199203.tif
# Flipped spi_200101.tif and saved to spi_tiffs_final/spi_200101.tif
# Flipped spi_199405.tif and saved to spi_tiffs_final/spi_199405.tif
# Flipped spi_199411.tif and saved to spi_tiffs_final/spi_199411.tif
# Flipped spi_200908.tif and saved to spi_tiffs_final/spi_200908.tif
# Flipped spi_202104.tif and saved to spi_tiffs_final/spi_202104.tif
# Flipped spi_200707.tif and saved to spi_tiffs_final/spi_200707.tif
# Flipped spi_202110.tif and saved to spi_tiffs_final/spi_202110.tif
# Flipped spi_199607.tif and saved to spi_tiffs_final/spi_199607.tif
# Flipped spi_199808.tif and saved to spi_tiffs_final/spi_199808.tif
# Flipped spi_200511.tif and saved to spi_tiffs_final/spi_200511.tif
# Flipped spi_200505.tif and saved to spi_tiffs_final/spi_200505.tif
# Flipped spi_200507.tif and saved to spi_tiffs_final/spi_200507.tif
# Flipped spi_201802.tif and saved to spi_tiffs_final/spi_201802.tif
# Flipped spi_199605.tif and saved to spi_tiffs_final/spi_199605.tif
# Flipped spi_199611.tif and saved to spi_tiffs_final/spi_199611.tif
# Flipped spi_200711.tif and saved to spi_tiffs_final/spi_200711.tif
# Flipped spi_202106.tif and saved to spi_tiffs_final/spi_202106.tif
# Flipped spi_202112.tif and saved to spi_tiffs_final/spi_202112.tif
# Flipped spi_200705.tif and saved to spi_tiffs_final/spi_200705.tif
# Flipped spi_198902.tif and saved to spi_tiffs_final/spi_198902.tif
# Flipped spi_199407.tif and saved to spi_tiffs_final/spi_199407.tif
# Flipped spi_200103.tif and saved to spi_tiffs_final/spi_200103.tif
# Flipped spi_201209.tif and saved to spi_tiffs_final/spi_201209.tif
# Flipped spi_199201.tif and saved to spi_tiffs_final/spi_199201.tif
# Flipped spi_200301.tif and saved to spi_tiffs_final/spi_200301.tif
# Flipped spi_198309.tif and saved to spi_tiffs_final/spi_198309.tif
# Flipped spi_199003.tif and saved to spi_tiffs_final/spi_199003.tif
# Flipped spi_199002.tif and saved to spi_tiffs_final/spi_199002.tif
# Flipped spi_198308.tif and saved to spi_tiffs_final/spi_198308.tif
# Flipped spi_201208.tif and saved to spi_tiffs_final/spi_201208.tif
# Flipped spi_200102.tif and saved to spi_tiffs_final/spi_200102.tif
# Flipped spi_199412.tif and saved to spi_tiffs_final/spi_199412.tif
# Flipped spi_199406.tif and saved to spi_tiffs_final/spi_199406.tif
# Flipped spi_198903.tif and saved to spi_tiffs_final/spi_198903.tif
# Flipped spi_200704.tif and saved to spi_tiffs_final/spi_200704.tif
# Flipped spi_202107.tif and saved to spi_tiffs_final/spi_202107.tif
# Flipped spi_200710.tif and saved to spi_tiffs_final/spi_200710.tif
# Flipped spi_199610.tif and saved to spi_tiffs_final/spi_199610.tif
# Flipped spi_199604.tif and saved to spi_tiffs_final/spi_199604.tif
# Flipped spi_201803.tif and saved to spi_tiffs_final/spi_201803.tif
# Flipped spi_200506.tif and saved to spi_tiffs_final/spi_200506.tif
# Flipped spi_200512.tif and saved to spi_tiffs_final/spi_200512.tif
# Flipped spi_201608.tif and saved to spi_tiffs_final/spi_201608.tif
# Flipped spi_200502.tif and saved to spi_tiffs_final/spi_200502.tif
# Flipped spi_201807.tif and saved to spi_tiffs_final/spi_201807.tif
# Flipped spi_198907.tif and saved to spi_tiffs_final/spi_198907.tif
# Flipped spi_202103.tif and saved to spi_tiffs_final/spi_202103.tif
# Flipped spi_199402.tif and saved to spi_tiffs_final/spi_199402.tif
# Flipped spi_198708.tif and saved to spi_tiffs_final/spi_198708.tif
# Flipped spi_200106.tif and saved to spi_tiffs_final/spi_200106.tif
# Flipped spi_200112.tif and saved to spi_tiffs_final/spi_200112.tif
# Flipped spi_199210.tif and saved to spi_tiffs_final/spi_199210.tif
# Flipped spi_199204.tif and saved to spi_tiffs_final/spi_199204.tif
# Flipped spi_200304.tif and saved to spi_tiffs_final/spi_200304.tif
# Flipped spi_200310.tif and saved to spi_tiffs_final/spi_200310.tif
# Flipped spi_199012.tif and saved to spi_tiffs_final/spi_199012.tif
# Flipped spi_199006.tif and saved to spi_tiffs_final/spi_199006.tif
# Flipped spi_199007.tif and saved to spi_tiffs_final/spi_199007.tif
# Flipped spi_200311.tif and saved to spi_tiffs_final/spi_200311.tif
# Flipped spi_200305.tif and saved to spi_tiffs_final/spi_200305.tif
# Flipped spi_199205.tif and saved to spi_tiffs_final/spi_199205.tif
# Flipped spi_199211.tif and saved to spi_tiffs_final/spi_199211.tif
# Flipped spi_200107.tif and saved to spi_tiffs_final/spi_200107.tif
# Flipped spi_199602.tif and saved to spi_tiffs_final/spi_199602.tif
# Flipped spi_198508.tif and saved to spi_tiffs_final/spi_198508.tif
# Flipped spi_200201.tif and saved to spi_tiffs_final/spi_200201.tif
# Flipped spi_198209.tif and saved to spi_tiffs_final/spi_198209.tif
# Flipped spi_199103.tif and saved to spi_tiffs_final/spi_199103.tif
# Flipped spi_200003.tif and saved to spi_tiffs_final/spi_200003.tif
# Flipped spi_201309.tif and saved to spi_tiffs_final/spi_201309.tif
# Flipped spi_199301.tif and saved to spi_tiffs_final/spi_199301.tif
# Flipped spi_200611.tif and saved to spi_tiffs_final/spi_200611.tif
# Flipped spi_202006.tif and saved to spi_tiffs_final/spi_202006.tif
# Flipped spi_202012.tif and saved to spi_tiffs_final/spi_202012.tif
# Flipped spi_200605.tif and saved to spi_tiffs_final/spi_200605.tif
# Flipped spi_198802.tif and saved to spi_tiffs_final/spi_198802.tif
# Flipped spi_199507.tif and saved to spi_tiffs_final/spi_199507.tif
# Flipped spi_202204.tif and saved to spi_tiffs_final/spi_202204.tif
# Flipped spi_200407.tif and saved to spi_tiffs_final/spi_200407.tif
# Flipped spi_202210.tif and saved to spi_tiffs_final/spi_202210.tif
# Flipped spi_201902.tif and saved to spi_tiffs_final/spi_201902.tif
# Flipped spi_199705.tif and saved to spi_tiffs_final/spi_199705.tif
# Flipped spi_199711.tif and saved to spi_tiffs_final/spi_199711.tif
# Flipped spi_199710.tif and saved to spi_tiffs_final/spi_199710.tif
# Flipped spi_199704.tif and saved to spi_tiffs_final/spi_199704.tif
# Flipped spi_201903.tif and saved to spi_tiffs_final/spi_201903.tif
# Flipped spi_202211.tif and saved to spi_tiffs_final/spi_202211.tif
# Flipped spi_200406.tif and saved to spi_tiffs_final/spi_200406.tif
# Flipped spi_200412.tif and saved to spi_tiffs_final/spi_200412.tif
# Flipped spi_202205.tif and saved to spi_tiffs_final/spi_202205.tif
# Flipped spi_199512.tif and saved to spi_tiffs_final/spi_199512.tif
# Flipped spi_199506.tif and saved to spi_tiffs_final/spi_199506.tif
# Flipped spi_198803.tif and saved to spi_tiffs_final/spi_198803.tif
# Flipped spi_200604.tif and saved to spi_tiffs_final/spi_200604.tif
# Flipped spi_202007.tif and saved to spi_tiffs_final/spi_202007.tif
# Flipped spi_200610.tif and saved to spi_tiffs_final/spi_200610.tif
# Flipped spi_201308.tif and saved to spi_tiffs_final/spi_201308.tif
# Flipped spi_200002.tif and saved to spi_tiffs_final/spi_200002.tif
# Flipped spi_199102.tif and saved to spi_tiffs_final/spi_199102.tif
# Flipped spi_198208.tif and saved to spi_tiffs_final/spi_198208.tif
# Flipped spi_201108.tif and saved to spi_tiffs_final/spi_201108.tif
# Flipped spi_200202.tif and saved to spi_tiffs_final/spi_200202.tif
# Flipped spi_199302.tif and saved to spi_tiffs_final/spi_199302.tif
# Flipped spi_202011.tif and saved to spi_tiffs_final/spi_202011.tif
# Flipped spi_200606.tif and saved to spi_tiffs_final/spi_200606.tif
# Flipped spi_200612.tif and saved to spi_tiffs_final/spi_200612.tif
# Flipped spi_202005.tif and saved to spi_tiffs_final/spi_202005.tif
# Flipped spi_198801.tif and saved to spi_tiffs_final/spi_198801.tif
# Flipped spi_200809.tif and saved to spi_tiffs_final/spi_200809.tif
# Flipped spi_199510.tif and saved to spi_tiffs_final/spi_199510.tif
# Flipped spi_199504.tif and saved to spi_tiffs_final/spi_199504.tif
# Flipped spi_200404.tif and saved to spi_tiffs_final/spi_200404.tif
# Flipped spi_202207.tif and saved to spi_tiffs_final/spi_202207.tif
# Flipped spi_200410.tif and saved to spi_tiffs_final/spi_200410.tif
# Flipped spi_199909.tif and saved to spi_tiffs_final/spi_199909.tif
# Flipped spi_201901.tif and saved to spi_tiffs_final/spi_201901.tif
# Flipped spi_199712.tif and saved to spi_tiffs_final/spi_199712.tif
# Flipped spi_199706.tif and saved to spi_tiffs_final/spi_199706.tif
# Flipped spi_199707.tif and saved to spi_tiffs_final/spi_199707.tif
# Flipped spi_199908.tif and saved to spi_tiffs_final/spi_199908.tif
# Flipped spi_200411.tif and saved to spi_tiffs_final/spi_200411.tif
# Flipped spi_202206.tif and saved to spi_tiffs_final/spi_202206.tif
# Flipped spi_202212.tif and saved to spi_tiffs_final/spi_202212.tif
# Flipped spi_200405.tif and saved to spi_tiffs_final/spi_200405.tif
# Flipped spi_199505.tif and saved to spi_tiffs_final/spi_199505.tif
# Flipped spi_199511.tif and saved to spi_tiffs_final/spi_199511.tif
# Flipped spi_200808.tif and saved to spi_tiffs_final/spi_200808.tif
# Flipped spi_202004.tif and saved to spi_tiffs_final/spi_202004.tif
# Flipped spi_200607.tif and saved to spi_tiffs_final/spi_200607.tif
# Flipped spi_202010.tif and saved to spi_tiffs_final/spi_202010.tif
# Flipped spi_199303.tif and saved to spi_tiffs_final/spi_199303.tif
# Flipped spi_200001.tif and saved to spi_tiffs_final/spi_200001.tif
# Flipped spi_199101.tif and saved to spi_tiffs_final/spi_199101.tif
# Flipped spi_200203.tif and saved to spi_tiffs_final/spi_200203.tif
# Flipped spi_201109.tif and saved to spi_tiffs_final/spi_201109.tif
# Flipped spi_200207.tif and saved to spi_tiffs_final/spi_200207.tif
# Flipped spi_199105.tif and saved to spi_tiffs_final/spi_199105.tif
# Flipped spi_199111.tif and saved to spi_tiffs_final/spi_199111.tif
# Flipped spi_200011.tif and saved to spi_tiffs_final/spi_200011.tif
# Flipped spi_200005.tif and saved to spi_tiffs_final/spi_200005.tif
# Flipped spi_199307.tif and saved to spi_tiffs_final/spi_199307.tif
# Flipped spi_198810.tif and saved to spi_tiffs_final/spi_198810.tif
# Flipped spi_198804.tif and saved to spi_tiffs_final/spi_198804.tif
# Flipped spi_200603.tif and saved to spi_tiffs_final/spi_200603.tif
# Flipped spi_201509.tif and saved to spi_tiffs_final/spi_201509.tif
# Flipped spi_199501.tif and saved to spi_tiffs_final/spi_199501.tif
# Flipped spi_200401.tif and saved to spi_tiffs_final/spi_200401.tif
# Flipped spi_202202.tif and saved to spi_tiffs_final/spi_202202.tif
# Flipped spi_198409.tif and saved to spi_tiffs_final/spi_198409.tif
# Flipped spi_199408.tif and saved to spi_tiffs_final/spi_199408.tif
# Flipped spi_198702.tif and saved to spi_tiffs_final/spi_198702.tif
# Flipped spi_201212.tif and saved to spi_tiffs_final/spi_201212.tif
# Flipped spi_201206.tif and saved to spi_tiffs_final/spi_201206.tif
# Flipped spi_201010.tif and saved to spi_tiffs_final/spi_201010.tif
# Flipped spi_201004.tif and saved to spi_tiffs_final/spi_201004.tif
# Flipped spi_198306.tif and saved to spi_tiffs_final/spi_198306.tif
# Flipped spi_198312.tif and saved to spi_tiffs_final/spi_198312.tif
# Flipped spi_198307.tif and saved to spi_tiffs_final/spi_198307.tif
# Flipped spi_201005.tif and saved to spi_tiffs_final/spi_201005.tif
# Flipped spi_201011.tif and saved to spi_tiffs_final/spi_201011.tif
# Flipped spi_201207.tif and saved to spi_tiffs_final/spi_201207.tif
# Flipped spi_198703.tif and saved to spi_tiffs_final/spi_198703.tif
# Flipped spi_199409.tif and saved to spi_tiffs_final/spi_199409.tif
# Flipped spi_200910.tif and saved to spi_tiffs_final/spi_200910.tif
# Flipped spi_200904.tif and saved to spi_tiffs_final/spi_200904.tif
# Flipped spi_201401.tif and saved to spi_tiffs_final/spi_201401.tif
# Flipped spi_202108.tif and saved to spi_tiffs_final/spi_202108.tif
# Flipped spi_198501.tif and saved to spi_tiffs_final/spi_198501.tif
# Flipped spi_199804.tif and saved to spi_tiffs_final/spi_199804.tif
# Flipped spi_199810.tif and saved to spi_tiffs_final/spi_199810.tif
# Flipped spi_200509.tif and saved to spi_tiffs_final/spi_200509.tif
# Flipped spi_201603.tif and saved to spi_tiffs_final/spi_201603.tif

# %% [markdown]
# Filter the missing CY values from dataset (<70%)

# %%
import os
import rasterio
import numpy as np
from rasterio.enums import Resampling
from rasterio.transform import Affine

# Define input and output directories
input_folder = 'spi_tiffs_final'
output_folder = 'spi_tiffs_final_1982-2022'

# Make sure the output directory exists
os.makedirs(output_folder, exist_ok=True)

# Iterate over all files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith('.tif'):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)
        
        # Open the input .tif file
        with rasterio.open(input_path) as src:
            # Read the single band data
            data = src.read(1)  # Read the first band only
            
            # Get metadata and dimensions
            metadata = src.meta.copy()
            height = metadata['height']
            width = metadata['width']
            transform = src.transform
            
            # Calculate new transform to shift the image south
            new_transform = transform * Affine.translation(0, -height)
            
            # Create a new array for the shifted data
            shifted_data = np.full((height, width), src.nodata, dtype=data.dtype)
            shifted_data[:height] = data
            
            # Write the shifted data to a new .tif file
            metadata.update({
                'transform': new_transform,
                'height': height,
                'width': width
            })
            
            with rasterio.open(output_path, 'w', **metadata) as dst:
                dst.write(shifted_data, 1)  # Write to the first band

        print(f"Shifted {filename} south by its length and saved to {output_path}")
# Out:
# Shifted spi_200504.tif south by its length and saved to spi_tiffs_final1/spi_200504.tif
# Shifted spi_200510.tif south by its length and saved to spi_tiffs_final1/spi_200510.tif
# Shifted spi_199809.tif south by its length and saved to spi_tiffs_final1/spi_199809.tif
# Shifted spi_201801.tif south by its length and saved to spi_tiffs_final1/spi_201801.tif
# Shifted spi_199612.tif south by its length and saved to spi_tiffs_final1/spi_199612.tif
# Shifted spi_199606.tif south by its length and saved to spi_tiffs_final1/spi_199606.tif
# Shifted spi_202111.tif south by its length and saved to spi_tiffs_final1/spi_202111.tif
# Shifted spi_200706.tif south by its length and saved to spi_tiffs_final1/spi_200706.tif
# Shifted spi_200712.tif south by its length and saved to spi_tiffs_final1/spi_200712.tif
# Shifted spi_202105.tif south by its length and saved to spi_tiffs_final1/spi_202105.tif
# Shifted spi_198901.tif south by its length and saved to spi_tiffs_final1/spi_198901.tif
# Shifted spi_200909.tif south by its length and saved to spi_tiffs_final1/spi_200909.tif
# Shifted spi_199410.tif south by its length and saved to spi_tiffs_final1/spi_199410.tif
# Shifted spi_199404.tif south by its length and saved to spi_tiffs_final1/spi_199404.tif
# Shifted spi_199202.tif south by its length and saved to spi_tiffs_final1/spi_199202.tif
# Shifted spi_201008.tif south by its length and saved to spi_tiffs_final1/spi_201008.tif
# Shifted spi_200302.tif south by its length and saved to spi_tiffs_final1/spi_200302.tif
# Shifted spi_199001.tif south by its length and saved to spi_tiffs_final1/spi_199001.tif
# Shifted spi_200303.tif south by its length and saved to spi_tiffs_final1/spi_200303.tif
# Shifted spi_201009.tif south by its length and saved to spi_tiffs_final1/spi_201009.tif
# Shifted spi_199203.tif south by its length and saved to spi_tiffs_final1/spi_199203.tif
# Shifted spi_200101.tif south by its length and saved to spi_tiffs_final1/spi_200101.tif
# Shifted spi_199405.tif south by its length and saved to spi_tiffs_final1/spi_199405.tif
# Shifted spi_199411.tif south by its length and saved to spi_tiffs_final1/spi_199411.tif
# Shifted spi_200908.tif south by its length and saved to spi_tiffs_final1/spi_200908.tif
# Shifted spi_202104.tif south by its length and saved to spi_tiffs_final1/spi_202104.tif
# Shifted spi_200707.tif south by its length and saved to spi_tiffs_final1/spi_200707.tif
# Shifted spi_202110.tif south by its length and saved to spi_tiffs_final1/spi_202110.tif
# Shifted spi_199607.tif south by its length and saved to spi_tiffs_final1/spi_199607.tif
# Shifted spi_199808.tif south by its length and saved to spi_tiffs_final1/spi_199808.tif
# Shifted spi_200511.tif south by its length and saved to spi_tiffs_final1/spi_200511.tif
# Shifted spi_200505.tif south by its length and saved to spi_tiffs_final1/spi_200505.tif
# Shifted spi_200507.tif south by its length and saved to spi_tiffs_final1/spi_200507.tif
# Shifted spi_201802.tif south by its length and saved to spi_tiffs_final1/spi_201802.tif
# Shifted spi_199605.tif south by its length and saved to spi_tiffs_final1/spi_199605.tif
# Shifted spi_199611.tif south by its length and saved to spi_tiffs_final1/spi_199611.tif
# Shifted spi_200711.tif south by its length and saved to spi_tiffs_final1/spi_200711.tif
# Shifted spi_202106.tif south by its length and saved to spi_tiffs_final1/spi_202106.tif
# Shifted spi_202112.tif south by its length and saved to spi_tiffs_final1/spi_202112.tif
# Shifted spi_200705.tif south by its length and saved to spi_tiffs_final1/spi_200705.tif
# Shifted spi_198902.tif south by its length and saved to spi_tiffs_final1/spi_198902.tif
# Shifted spi_199407.tif south by its length and saved to spi_tiffs_final1/spi_199407.tif
# Shifted spi_200103.tif south by its length and saved to spi_tiffs_final1/spi_200103.tif
# Shifted spi_201209.tif south by its length and saved to spi_tiffs_final1/spi_201209.tif
# Shifted spi_199201.tif south by its length and saved to spi_tiffs_final1/spi_199201.tif
# Shifted spi_200301.tif south by its length and saved to spi_tiffs_final1/spi_200301.tif
# Shifted spi_198309.tif south by its length and saved to spi_tiffs_final1/spi_198309.tif
# Shifted spi_199003.tif south by its length and saved to spi_tiffs_final1/spi_199003.tif
# Shifted spi_199002.tif south by its length and saved to spi_tiffs_final1/spi_199002.tif
# Shifted spi_198308.tif south by its length and saved to spi_tiffs_final1/spi_198308.tif
# Shifted spi_201208.tif south by its length and saved to spi_tiffs_final1/spi_201208.tif
# Shifted spi_200102.tif south by its length and saved to spi_tiffs_final1/spi_200102.tif
# Shifted spi_199412.tif south by its length and saved to spi_tiffs_final1/spi_199412.tif
# Shifted spi_199406.tif south by its length and saved to spi_tiffs_final1/spi_199406.tif
# Shifted spi_198903.tif south by its length and saved to spi_tiffs_final1/spi_198903.tif
# Shifted spi_200704.tif south by its length and saved to spi_tiffs_final1/spi_200704.tif
# Shifted spi_202107.tif south by its length and saved to spi_tiffs_final1/spi_202107.tif
# Shifted spi_200710.tif south by its length and saved to spi_tiffs_final1/spi_200710.tif
# Shifted spi_199610.tif south by its length and saved to spi_tiffs_final1/spi_199610.tif
# Shifted spi_199604.tif south by its length and saved to spi_tiffs_final1/spi_199604.tif
# Shifted spi_201803.tif south by its length and saved to spi_tiffs_final1/spi_201803.tif
# Shifted spi_200506.tif south by its length and saved to spi_tiffs_final1/spi_200506.tif
# Shifted spi_200512.tif south by its length and saved to spi_tiffs_final1/spi_200512.tif
# Shifted spi_201608.tif south by its length and saved to spi_tiffs_final1/spi_201608.tif
# Shifted spi_200502.tif south by its length and saved to spi_tiffs_final1/spi_200502.tif
# Shifted spi_201807.tif south by its length and saved to spi_tiffs_final1/spi_201807.tif
# Shifted spi_198907.tif south by its length and saved to spi_tiffs_final1/spi_198907.tif
# Shifted spi_202103.tif south by its length and saved to spi_tiffs_final1/spi_202103.tif
# Shifted spi_199402.tif south by its length and saved to spi_tiffs_final1/spi_199402.tif
# Shifted spi_198708.tif south by its length and saved to spi_tiffs_final1/spi_198708.tif
# Shifted spi_200106.tif south by its length and saved to spi_tiffs_final1/spi_200106.tif
# Shifted spi_200112.tif south by its length and saved to spi_tiffs_final1/spi_200112.tif
# Shifted spi_199210.tif south by its length and saved to spi_tiffs_final1/spi_199210.tif
# Shifted spi_199204.tif south by its length and saved to spi_tiffs_final1/spi_199204.tif
# Shifted spi_200304.tif south by its length and saved to spi_tiffs_final1/spi_200304.tif
# Shifted spi_200310.tif south by its length and saved to spi_tiffs_final1/spi_200310.tif
# Shifted spi_199012.tif south by its length and saved to spi_tiffs_final1/spi_199012.tif
# Shifted spi_199006.tif south by its length and saved to spi_tiffs_final1/spi_199006.tif
# Shifted spi_199007.tif south by its length and saved to spi_tiffs_final1/spi_199007.tif
# Shifted spi_200311.tif south by its length and saved to spi_tiffs_final1/spi_200311.tif
# Shifted spi_200305.tif south by its length and saved to spi_tiffs_final1/spi_200305.tif
# Shifted spi_199205.tif south by its length and saved to spi_tiffs_final1/spi_199205.tif
# Shifted spi_199211.tif south by its length and saved to spi_tiffs_final1/spi_199211.tif
# Shifted spi_200107.tif south by its length and saved to spi_tiffs_final1/spi_200107.tif
# Shifted spi_198709.tif south by its length and saved to spi_tiffs_final1/spi_198709.tif
# Shifted spi_199403.tif south by its length and saved to spi_tiffs_final1/spi_199403.tif
# Shifted spi_200701.tif south by its length and saved to spi_tiffs_final1/spi_200701.tif
# Shifted spi_202102.tif south by its length and saved to spi_tiffs_final1/spi_202102.tif
# Shifted spi_198912.tif south by its length and saved to spi_tiffs_final1/spi_198912.tif
# Shifted spi_198906.tif south by its length and saved to spi_tiffs_final1/spi_198906.tif
# Shifted spi_201806.tif south by its length and saved to spi_tiffs_final1/spi_201806.tif
# Shifted spi_201812.tif south by its length and saved to spi_tiffs_final1/spi_201812.tif
# Shifted spi_199601.tif south by its length and saved to spi_tiffs_final1/spi_199601.tif
# Shifted spi_200503.tif south by its length and saved to spi_tiffs_final1/spi_200503.tif
# Shifted spi_201609.tif south by its length and saved to spi_tiffs_final1/spi_201609.tif
# Shifted spi_200501.tif south by its length and saved to spi_tiffs_final1/spi_200501.tif
# Shifted spi_198509.tif south by its length and saved to spi_tiffs_final1/spi_198509.tif
# Shifted spi_199603.tif south by its length and saved to spi_tiffs_final1/spi_199603.tif
# Shifted spi_201804.tif south by its length and saved to spi_tiffs_final1/spi_201804.tif
# Shifted spi_201810.tif south by its length and saved to spi_tiffs_final1/spi_201810.tif
# Shifted spi_198910.tif south by its length and saved to spi_tiffs_final1/spi_198910.tif
# Shifted spi_198904.tif south by its length and saved to spi_tiffs_final1/spi_198904.tif
# Shifted spi_200703.tif south by its length and saved to spi_tiffs_final1/spi_200703.tif
# Shifted spi_201409.tif south by its length and saved to spi_tiffs_final1/spi_201409.tif
# Shifted spi_199401.tif south by its length and saved to spi_tiffs_final1/spi_199401.tif
# Shifted spi_200111.tif south by its length and saved to spi_tiffs_final1/spi_200111.tif
# Shifted spi_200105.tif south by its length and saved to spi_tiffs_final1/spi_200105.tif
# Shifted spi_199207.tif south by its length and saved to spi_tiffs_final1/spi_199207.tif
# Shifted spi_200307.tif south by its length and saved to spi_tiffs_final1/spi_200307.tif
# Shifted spi_199005.tif south by its length and saved to spi_tiffs_final1/spi_199005.tif
# Shifted spi_199011.tif south by its length and saved to spi_tiffs_final1/spi_199011.tif
# Shifted spi_199010.tif south by its length and saved to spi_tiffs_final1/spi_199010.tif
# Shifted spi_199004.tif south by its length and saved to spi_tiffs_final1/spi_199004.tif
# Shifted spi_200306.tif south by its length and saved to spi_tiffs_final1/spi_200306.tif
# Shifted spi_200312.tif south by its length and saved to spi_tiffs_final1/spi_200312.tif
# Shifted spi_199212.tif south by its length and saved to spi_tiffs_final1/spi_199212.tif
# Shifted spi_199206.tif south by its length and saved to spi_tiffs_final1/spi_199206.tif
# Shifted spi_200104.tif south by its length and saved to spi_tiffs_final1/spi_200104.tif
# Shifted spi_200110.tif south by its length and saved to spi_tiffs_final1/spi_200110.tif
# Shifted spi_202101.tif south by its length and saved to spi_tiffs_final1/spi_202101.tif
# Shifted spi_201408.tif south by its length and saved to spi_tiffs_final1/spi_201408.tif
# Shifted spi_200702.tif south by its length and saved to spi_tiffs_final1/spi_200702.tif
# Shifted spi_198905.tif south by its length and saved to spi_tiffs_final1/spi_198905.tif
# Shifted spi_198911.tif south by its length and saved to spi_tiffs_final1/spi_198911.tif
# Shifted spi_201811.tif south by its length and saved to spi_tiffs_final1/spi_201811.tif
# Shifted spi_201805.tif south by its length and saved to spi_tiffs_final1/spi_201805.tif
# Shifted spi_199602.tif south by its length and saved to spi_tiffs_final1/spi_199602.tif
# Shifted spi_198508.tif south by its length and saved to spi_tiffs_final1/spi_198508.tif
# Shifted spi_200201.tif south by its length and saved to spi_tiffs_final1/spi_200201.tif
# Shifted spi_198209.tif south by its length and saved to spi_tiffs_final1/spi_198209.tif
# Shifted spi_199103.tif south by its length and saved to spi_tiffs_final1/spi_199103.tif
# Shifted spi_200003.tif south by its length and saved to spi_tiffs_final1/spi_200003.tif
# Shifted spi_201309.tif south by its length and saved to spi_tiffs_final1/spi_201309.tif
# Shifted spi_199301.tif south by its length and saved to spi_tiffs_final1/spi_199301.tif
# Shifted spi_200611.tif south by its length and saved to spi_tiffs_final1/spi_200611.tif
# Shifted spi_202006.tif south by its length and saved to spi_tiffs_final1/spi_202006.tif
# Shifted spi_202012.tif south by its length and saved to spi_tiffs_final1/spi_202012.tif
# Shifted spi_200605.tif south by its length and saved to spi_tiffs_final1/spi_200605.tif
# Shifted spi_198802.tif south by its length and saved to spi_tiffs_final1/spi_198802.tif
# Shifted spi_199507.tif south by its length and saved to spi_tiffs_final1/spi_199507.tif
# Shifted spi_202204.tif south by its length and saved to spi_tiffs_final1/spi_202204.tif
# Shifted spi_200407.tif south by its length and saved to spi_tiffs_final1/spi_200407.tif
# Shifted spi_202210.tif south by its length and saved to spi_tiffs_final1/spi_202210.tif
# Shifted spi_201902.tif south by its length and saved to spi_tiffs_final1/spi_201902.tif
# Shifted spi_199705.tif south by its length and saved to spi_tiffs_final1/spi_199705.tif
# Shifted spi_199711.tif south by its length and saved to spi_tiffs_final1/spi_199711.tif
# Shifted spi_199710.tif south by its length and saved to spi_tiffs_final1/spi_199710.tif
# Shifted spi_199704.tif south by its length and saved to spi_tiffs_final1/spi_199704.tif
# Shifted spi_201903.tif south by its length and saved to spi_tiffs_final1/spi_201903.tif
# Shifted spi_202211.tif south by its length and saved to spi_tiffs_final1/spi_202211.tif
# Shifted spi_200406.tif south by its length and saved to spi_tiffs_final1/spi_200406.tif
# Shifted spi_200412.tif south by its length and saved to spi_tiffs_final1/spi_200412.tif
# Shifted spi_202205.tif south by its length and saved to spi_tiffs_final1/spi_202205.tif
# Shifted spi_199512.tif south by its length and saved to spi_tiffs_final1/spi_199512.tif
# Shifted spi_199506.tif south by its length and saved to spi_tiffs_final1/spi_199506.tif
# Shifted spi_198803.tif south by its length and saved to spi_tiffs_final1/spi_198803.tif
# Shifted spi_200604.tif south by its length and saved to spi_tiffs_final1/spi_200604.tif
# Shifted spi_202007.tif south by its length and saved to spi_tiffs_final1/spi_202007.tif
# Shifted spi_200610.tif south by its length and saved to spi_tiffs_final1/spi_200610.tif
# Shifted spi_201308.tif south by its length and saved to spi_tiffs_final1/spi_201308.tif
# Shifted spi_200002.tif south by its length and saved to spi_tiffs_final1/spi_200002.tif
# Shifted spi_199102.tif south by its length and saved to spi_tiffs_final1/spi_199102.tif
# Shifted spi_198208.tif south by its length and saved to spi_tiffs_final1/spi_198208.tif
# Shifted spi_201108.tif south by its length and saved to spi_tiffs_final1/spi_201108.tif
# Shifted spi_200202.tif south by its length and saved to spi_tiffs_final1/spi_200202.tif
# Shifted spi_199302.tif south by its length and saved to spi_tiffs_final1/spi_199302.tif
# Shifted spi_202011.tif south by its length and saved to spi_tiffs_final1/spi_202011.tif
# Shifted spi_200606.tif south by its length and saved to spi_tiffs_final1/spi_200606.tif
# Shifted spi_200612.tif south by its length and saved to spi_tiffs_final1/spi_200612.tif
# Shifted spi_202005.tif south by its length and saved to spi_tiffs_final1/spi_202005.tif
# Shifted spi_198801.tif south by its length and saved to spi_tiffs_final1/spi_198801.tif
# Shifted spi_200809.tif south by its length and saved to spi_tiffs_final1/spi_200809.tif
# Shifted spi_199510.tif south by its length and saved to spi_tiffs_final1/spi_199510.tif
# Shifted spi_199504.tif south by its length and saved to spi_tiffs_final1/spi_199504.tif
# Shifted spi_200404.tif south by its length and saved to spi_tiffs_final1/spi_200404.tif
# Shifted spi_202207.tif south by its length and saved to spi_tiffs_final1/spi_202207.tif
# Shifted spi_200410.tif south by its length and saved to spi_tiffs_final1/spi_200410.tif
# Shifted spi_199909.tif south by its length and saved to spi_tiffs_final1/spi_199909.tif
# Shifted spi_201901.tif south by its length and saved to spi_tiffs_final1/spi_201901.tif
# Shifted spi_199712.tif south by its length and saved to spi_tiffs_final1/spi_199712.tif
# Shifted spi_199706.tif south by its length and saved to spi_tiffs_final1/spi_199706.tif
# Shifted spi_199707.tif south by its length and saved to spi_tiffs_final1/spi_199707.tif
# Shifted spi_199908.tif south by its length and saved to spi_tiffs_final1/spi_199908.tif
# Shifted spi_200411.tif south by its length and saved to spi_tiffs_final1/spi_200411.tif
# Shifted spi_202206.tif south by its length and saved to spi_tiffs_final1/spi_202206.tif
# Shifted spi_202212.tif south by its length and saved to spi_tiffs_final1/spi_202212.tif
# Shifted spi_200405.tif south by its length and saved to spi_tiffs_final1/spi_200405.tif
# Shifted spi_199505.tif south by its length and saved to spi_tiffs_final1/spi_199505.tif
# Shifted spi_199511.tif south by its length and saved to spi_tiffs_final1/spi_199511.tif
# Shifted spi_200808.tif south by its length and saved to spi_tiffs_final1/spi_200808.tif
# Shifted spi_202004.tif south by its length and saved to spi_tiffs_final1/spi_202004.tif
# Shifted spi_200607.tif south by its length and saved to spi_tiffs_final1/spi_200607.tif
# Shifted spi_202010.tif south by its length and saved to spi_tiffs_final1/spi_202010.tif
# Shifted spi_199303.tif south by its length and saved to spi_tiffs_final1/spi_199303.tif
# Shifted spi_200001.tif south by its length and saved to spi_tiffs_final1/spi_200001.tif
# Shifted spi_199101.tif south by its length and saved to spi_tiffs_final1/spi_199101.tif
# Shifted spi_200203.tif south by its length and saved to spi_tiffs_final1/spi_200203.tif
# Shifted spi_201109.tif south by its length and saved to spi_tiffs_final1/spi_201109.tif
# Shifted spi_200207.tif south by its length and saved to spi_tiffs_final1/spi_200207.tif
# Shifted spi_199105.tif south by its length and saved to spi_tiffs_final1/spi_199105.tif
# Shifted spi_199111.tif south by its length and saved to spi_tiffs_final1/spi_199111.tif
# Shifted spi_200011.tif south by its length and saved to spi_tiffs_final1/spi_200011.tif
# Shifted spi_200005.tif south by its length and saved to spi_tiffs_final1/spi_200005.tif
# Shifted spi_199307.tif south by its length and saved to spi_tiffs_final1/spi_199307.tif
# Shifted spi_198810.tif south by its length and saved to spi_tiffs_final1/spi_198810.tif
# Shifted spi_198804.tif south by its length and saved to spi_tiffs_final1/spi_198804.tif
# Shifted spi_200603.tif south by its length and saved to spi_tiffs_final1/spi_200603.tif
# Shifted spi_201509.tif south by its length and saved to spi_tiffs_final1/spi_201509.tif
# Shifted spi_199501.tif south by its length and saved to spi_tiffs_final1/spi_199501.tif
# Shifted spi_200401.tif south by its length and saved to spi_tiffs_final1/spi_200401.tif
# Shifted spi_202202.tif south by its length and saved to spi_tiffs_final1/spi_202202.tif
# Shifted spi_198409.tif south by its length and saved to spi_tiffs_final1/spi_198409.tif
# Shifted spi_199703.tif south by its length and saved to spi_tiffs_final1/spi_199703.tif
# Shifted spi_201904.tif south by its length and saved to spi_tiffs_final1/spi_201904.tif
# Shifted spi_201910.tif south by its length and saved to spi_tiffs_final1/spi_201910.tif
# Shifted spi_201911.tif south by its length and saved to spi_tiffs_final1/spi_201911.tif
# Shifted spi_201905.tif south by its length and saved to spi_tiffs_final1/spi_201905.tif
# Shifted spi_199702.tif south by its length and saved to spi_tiffs_final1/spi_199702.tif
# Shifted spi_198408.tif south by its length and saved to spi_tiffs_final1/spi_198408.tif
# Shifted spi_202203.tif south by its length and saved to spi_tiffs_final1/spi_202203.tif
# Shifted spi_202001.tif south by its length and saved to spi_tiffs_final1/spi_202001.tif
# Shifted spi_201508.tif south by its length and saved to spi_tiffs_final1/spi_201508.tif
# Shifted spi_200602.tif south by its length and saved to spi_tiffs_final1/spi_200602.tif
# Shifted spi_198805.tif south by its length and saved to spi_tiffs_final1/spi_198805.tif
# Shifted spi_198811.tif south by its length and saved to spi_tiffs_final1/spi_198811.tif
# Shifted spi_199312.tif south by its length and saved to spi_tiffs_final1/spi_199312.tif
# Shifted spi_199306.tif south by its length and saved to spi_tiffs_final1/spi_199306.tif
# Shifted spi_200004.tif south by its length and saved to spi_tiffs_final1/spi_200004.tif
# Shifted spi_200010.tif south by its length and saved to spi_tiffs_final1/spi_200010.tif
# Shifted spi_199110.tif south by its length and saved to spi_tiffs_final1/spi_199110.tif
# Shifted spi_199104.tif south by its length and saved to spi_tiffs_final1/spi_199104.tif
# Shifted spi_200206.tif south by its length and saved to spi_tiffs_final1/spi_200206.tif
# Shifted spi_200212.tif south by its length and saved to spi_tiffs_final1/spi_200212.tif
# Shifted spi_200204.tif south by its length and saved to spi_tiffs_final1/spi_200204.tif
# Shifted spi_200210.tif south by its length and saved to spi_tiffs_final1/spi_200210.tif
# Shifted spi_199112.tif south by its length and saved to spi_tiffs_final1/spi_199112.tif
# Shifted spi_199106.tif south by its length and saved to spi_tiffs_final1/spi_199106.tif
# Shifted spi_200006.tif south by its length and saved to spi_tiffs_final1/spi_200006.tif
# Shifted spi_200012.tif south by its length and saved to spi_tiffs_final1/spi_200012.tif
# Shifted spi_199310.tif south by its length and saved to spi_tiffs_final1/spi_199310.tif
# Shifted spi_199304.tif south by its length and saved to spi_tiffs_final1/spi_199304.tif
# Shifted spi_198807.tif south by its length and saved to spi_tiffs_final1/spi_198807.tif
# Shifted spi_202003.tif south by its length and saved to spi_tiffs_final1/spi_202003.tif
# Shifted spi_199502.tif south by its length and saved to spi_tiffs_final1/spi_199502.tif
# Shifted spi_198608.tif south by its length and saved to spi_tiffs_final1/spi_198608.tif
# Shifted spi_202201.tif south by its length and saved to spi_tiffs_final1/spi_202201.tif
# Shifted spi_201708.tif south by its length and saved to spi_tiffs_final1/spi_201708.tif
# Shifted spi_200402.tif south by its length and saved to spi_tiffs_final1/spi_200402.tif
# Shifted spi_201907.tif south by its length and saved to spi_tiffs_final1/spi_201907.tif
# Shifted spi_201906.tif south by its length and saved to spi_tiffs_final1/spi_201906.tif
# Shifted spi_201912.tif south by its length and saved to spi_tiffs_final1/spi_201912.tif
# Shifted spi_199701.tif south by its length and saved to spi_tiffs_final1/spi_199701.tif
# Shifted spi_200403.tif south by its length and saved to spi_tiffs_final1/spi_200403.tif
# Shifted spi_201709.tif south by its length and saved to spi_tiffs_final1/spi_201709.tif
# Shifted spi_198609.tif south by its length and saved to spi_tiffs_final1/spi_198609.tif
# Shifted spi_199503.tif south by its length and saved to spi_tiffs_final1/spi_199503.tif
# Shifted spi_200601.tif south by its length and saved to spi_tiffs_final1/spi_200601.tif
# Shifted spi_202002.tif south by its length and saved to spi_tiffs_final1/spi_202002.tif
# Shifted spi_198812.tif south by its length and saved to spi_tiffs_final1/spi_198812.tif
# Shifted spi_198806.tif south by its length and saved to spi_tiffs_final1/spi_198806.tif
# Shifted spi_199305.tif south by its length and saved to spi_tiffs_final1/spi_199305.tif
# Shifted spi_199311.tif south by its length and saved to spi_tiffs_final1/spi_199311.tif
# Shifted spi_200007.tif south by its length and saved to spi_tiffs_final1/spi_200007.tif
# Shifted spi_199107.tif south by its length and saved to spi_tiffs_final1/spi_199107.tif
# Shifted spi_200211.tif south by its length and saved to spi_tiffs_final1/spi_200211.tif
# Shifted spi_200205.tif south by its length and saved to spi_tiffs_final1/spi_200205.tif
# Shifted spi_201102.tif south by its length and saved to spi_tiffs_final1/spi_201102.tif
# Shifted spi_200208.tif south by its length and saved to spi_tiffs_final1/spi_200208.tif
# Shifted spi_199308.tif south by its length and saved to spi_tiffs_final1/spi_199308.tif
# Shifted spi_201512.tif south by its length and saved to spi_tiffs_final1/spi_201512.tif
# Shifted spi_201506.tif south by its length and saved to spi_tiffs_final1/spi_201506.tif
# Shifted spi_198604.tif south by its length and saved to spi_tiffs_final1/spi_198604.tif
# Shifted spi_198610.tif south by its length and saved to spi_tiffs_final1/spi_198610.tif
# Shifted spi_200803.tif south by its length and saved to spi_tiffs_final1/spi_200803.tif
# Shifted spi_199903.tif south by its length and saved to spi_tiffs_final1/spi_199903.tif
# Shifted spi_201710.tif south by its length and saved to spi_tiffs_final1/spi_201710.tif
# Shifted spi_201704.tif south by its length and saved to spi_tiffs_final1/spi_201704.tif
# Shifted spi_198406.tif south by its length and saved to spi_tiffs_final1/spi_198406.tif
# Shifted spi_198412.tif south by its length and saved to spi_tiffs_final1/spi_198412.tif
# Shifted spi_198407.tif south by its length and saved to spi_tiffs_final1/spi_198407.tif
# Shifted spi_201705.tif south by its length and saved to spi_tiffs_final1/spi_201705.tif
# Shifted spi_201711.tif south by its length and saved to spi_tiffs_final1/spi_201711.tif
# Shifted spi_199902.tif south by its length and saved to spi_tiffs_final1/spi_199902.tif
# Shifted spi_200802.tif south by its length and saved to spi_tiffs_final1/spi_200802.tif
# Shifted spi_198611.tif south by its length and saved to spi_tiffs_final1/spi_198611.tif
# Shifted spi_198605.tif south by its length and saved to spi_tiffs_final1/spi_198605.tif
# Shifted spi_201507.tif south by its length and saved to spi_tiffs_final1/spi_201507.tif
# Shifted spi_199309.tif south by its length and saved to spi_tiffs_final1/spi_199309.tif
# Shifted spi_201301.tif south by its length and saved to spi_tiffs_final1/spi_201301.tif
# Shifted spi_198201.tif south by its length and saved to spi_tiffs_final1/spi_198201.tif
# Shifted spi_200209.tif south by its length and saved to spi_tiffs_final1/spi_200209.tif
# Shifted spi_201103.tif south by its length and saved to spi_tiffs_final1/spi_201103.tif
# Shifted spi_201101.tif south by its length and saved to spi_tiffs_final1/spi_201101.tif
# Shifted spi_198203.tif south by its length and saved to spi_tiffs_final1/spi_198203.tif
# Shifted spi_199109.tif south by its length and saved to spi_tiffs_final1/spi_199109.tif
# Shifted spi_200009.tif south by its length and saved to spi_tiffs_final1/spi_200009.tif
# Shifted spi_201303.tif south by its length and saved to spi_tiffs_final1/spi_201303.tif
# Shifted spi_198808.tif south by its length and saved to spi_tiffs_final1/spi_198808.tif
# Shifted spi_201505.tif south by its length and saved to spi_tiffs_final1/spi_201505.tif
# Shifted spi_201511.tif south by its length and saved to spi_tiffs_final1/spi_201511.tif
# Shifted spi_198607.tif south by its length and saved to spi_tiffs_final1/spi_198607.tif
# Shifted spi_201707.tif south by its length and saved to spi_tiffs_final1/spi_201707.tif
# Shifted spi_198411.tif south by its length and saved to spi_tiffs_final1/spi_198411.tif
# Shifted spi_198405.tif south by its length and saved to spi_tiffs_final1/spi_198405.tif
# Shifted spi_201908.tif south by its length and saved to spi_tiffs_final1/spi_201908.tif
# Shifted spi_201909.tif south by its length and saved to spi_tiffs_final1/spi_201909.tif
# Shifted spi_198404.tif south by its length and saved to spi_tiffs_final1/spi_198404.tif
# Shifted spi_198410.tif south by its length and saved to spi_tiffs_final1/spi_198410.tif
# Shifted spi_201712.tif south by its length and saved to spi_tiffs_final1/spi_201712.tif
# Shifted spi_201706.tif south by its length and saved to spi_tiffs_final1/spi_201706.tif
# Shifted spi_199901.tif south by its length and saved to spi_tiffs_final1/spi_199901.tif
# Shifted spi_200801.tif south by its length and saved to spi_tiffs_final1/spi_200801.tif
# Shifted spi_198606.tif south by its length and saved to spi_tiffs_final1/spi_198606.tif
# Shifted spi_198612.tif south by its length and saved to spi_tiffs_final1/spi_198612.tif
# Shifted spi_201510.tif south by its length and saved to spi_tiffs_final1/spi_201510.tif
# Shifted spi_201504.tif south by its length and saved to spi_tiffs_final1/spi_201504.tif
# Shifted spi_198809.tif south by its length and saved to spi_tiffs_final1/spi_198809.tif
# Shifted spi_201302.tif south by its length and saved to spi_tiffs_final1/spi_201302.tif
# Shifted spi_200008.tif south by its length and saved to spi_tiffs_final1/spi_200008.tif
# Shifted spi_199108.tif south by its length and saved to spi_tiffs_final1/spi_199108.tif
# Shifted spi_198202.tif south by its length and saved to spi_tiffs_final1/spi_198202.tif
# Shifted spi_201110.tif south by its length and saved to spi_tiffs_final1/spi_201110.tif
# Shifted spi_201104.tif south by its length and saved to spi_tiffs_final1/spi_201104.tif
# Shifted spi_198206.tif south by its length and saved to spi_tiffs_final1/spi_198206.tif
# Shifted spi_198212.tif south by its length and saved to spi_tiffs_final1/spi_198212.tif
# Shifted spi_201312.tif south by its length and saved to spi_tiffs_final1/spi_201312.tif
# Shifted spi_201306.tif south by its length and saved to spi_tiffs_final1/spi_201306.tif
# Shifted spi_202009.tif south by its length and saved to spi_tiffs_final1/spi_202009.tif
# Shifted spi_200805.tif south by its length and saved to spi_tiffs_final1/spi_200805.tif
# Shifted spi_200811.tif south by its length and saved to spi_tiffs_final1/spi_200811.tif
# Shifted spi_199508.tif south by its length and saved to spi_tiffs_final1/spi_199508.tif
# Shifted spi_198602.tif south by its length and saved to spi_tiffs_final1/spi_198602.tif
# Shifted spi_201702.tif south by its length and saved to spi_tiffs_final1/spi_201702.tif
# Shifted spi_200408.tif south by its length and saved to spi_tiffs_final1/spi_200408.tif
# Shifted spi_199911.tif south by its length and saved to spi_tiffs_final1/spi_199911.tif
# Shifted spi_199905.tif south by its length and saved to spi_tiffs_final1/spi_199905.tif
# Shifted spi_198401.tif south by its length and saved to spi_tiffs_final1/spi_198401.tif
# Shifted spi_199904.tif south by its length and saved to spi_tiffs_final1/spi_199904.tif
# Shifted spi_199910.tif south by its length and saved to spi_tiffs_final1/spi_199910.tif
# Shifted spi_200409.tif south by its length and saved to spi_tiffs_final1/spi_200409.tif
# Shifted spi_201703.tif south by its length and saved to spi_tiffs_final1/spi_201703.tif
# Shifted spi_198603.tif south by its length and saved to spi_tiffs_final1/spi_198603.tif
# Shifted spi_199509.tif south by its length and saved to spi_tiffs_final1/spi_199509.tif
# Shifted spi_200810.tif south by its length and saved to spi_tiffs_final1/spi_200810.tif
# Shifted spi_200804.tif south by its length and saved to spi_tiffs_final1/spi_200804.tif
# Shifted spi_201501.tif south by its length and saved to spi_tiffs_final1/spi_201501.tif
# Shifted spi_202008.tif south by its length and saved to spi_tiffs_final1/spi_202008.tif
# Shifted spi_201307.tif south by its length and saved to spi_tiffs_final1/spi_201307.tif
# Shifted spi_198207.tif south by its length and saved to spi_tiffs_final1/spi_198207.tif
# Shifted spi_201105.tif south by its length and saved to spi_tiffs_final1/spi_201105.tif
# Shifted spi_201111.tif south by its length and saved to spi_tiffs_final1/spi_201111.tif
# Shifted spi_201107.tif south by its length and saved to spi_tiffs_final1/spi_201107.tif
# Shifted spi_198211.tif south by its length and saved to spi_tiffs_final1/spi_198211.tif
# Shifted spi_198205.tif south by its length and saved to spi_tiffs_final1/spi_198205.tif
# Shifted spi_201305.tif south by its length and saved to spi_tiffs_final1/spi_201305.tif
# Shifted spi_201311.tif south by its length and saved to spi_tiffs_final1/spi_201311.tif
# Shifted spi_200609.tif south by its length and saved to spi_tiffs_final1/spi_200609.tif
# Shifted spi_201503.tif south by its length and saved to spi_tiffs_final1/spi_201503.tif
# Shifted spi_200812.tif south by its length and saved to spi_tiffs_final1/spi_200812.tif
# Shifted spi_200806.tif south by its length and saved to spi_tiffs_final1/spi_200806.tif
# Shifted spi_198601.tif south by its length and saved to spi_tiffs_final1/spi_198601.tif
# Shifted spi_201701.tif south by its length and saved to spi_tiffs_final1/spi_201701.tif
# Shifted spi_202208.tif south by its length and saved to spi_tiffs_final1/spi_202208.tif
# Shifted spi_199906.tif south by its length and saved to spi_tiffs_final1/spi_199906.tif
# Shifted spi_199912.tif south by its length and saved to spi_tiffs_final1/spi_199912.tif
# Shifted spi_198403.tif south by its length and saved to spi_tiffs_final1/spi_198403.tif
# Shifted spi_199709.tif south by its length and saved to spi_tiffs_final1/spi_199709.tif
# Shifted spi_199708.tif south by its length and saved to spi_tiffs_final1/spi_199708.tif
# Shifted spi_198402.tif south by its length and saved to spi_tiffs_final1/spi_198402.tif
# Shifted spi_199907.tif south by its length and saved to spi_tiffs_final1/spi_199907.tif
# Shifted spi_202209.tif south by its length and saved to spi_tiffs_final1/spi_202209.tif
# Shifted spi_200807.tif south by its length and saved to spi_tiffs_final1/spi_200807.tif
# Shifted spi_201502.tif south by its length and saved to spi_tiffs_final1/spi_201502.tif
# Shifted spi_200608.tif south by its length and saved to spi_tiffs_final1/spi_200608.tif
# Shifted spi_201310.tif south by its length and saved to spi_tiffs_final1/spi_201310.tif
# Shifted spi_201304.tif south by its length and saved to spi_tiffs_final1/spi_201304.tif
# Shifted spi_198204.tif south by its length and saved to spi_tiffs_final1/spi_198204.tif
# Shifted spi_198210.tif south by its length and saved to spi_tiffs_final1/spi_198210.tif
# Shifted spi_201112.tif south by its length and saved to spi_tiffs_final1/spi_201112.tif
# Shifted spi_201106.tif south by its length and saved to spi_tiffs_final1/spi_201106.tif
# Shifted spi_201607.tif south by its length and saved to spi_tiffs_final1/spi_201607.tif
# Shifted spi_198511.tif south by its length and saved to spi_tiffs_final1/spi_198511.tif
# Shifted spi_198505.tif south by its length and saved to spi_tiffs_final1/spi_198505.tif
# Shifted spi_201808.tif south by its length and saved to spi_tiffs_final1/spi_201808.tif
# Shifted spi_198908.tif south by its length and saved to spi_tiffs_final1/spi_198908.tif
# Shifted spi_201405.tif south by its length and saved to spi_tiffs_final1/spi_201405.tif
# Shifted spi_201411.tif south by its length and saved to spi_tiffs_final1/spi_201411.tif
# Shifted spi_198707.tif south by its length and saved to spi_tiffs_final1/spi_198707.tif
# Shifted spi_200109.tif south by its length and saved to spi_tiffs_final1/spi_200109.tif
# Shifted spi_201203.tif south by its length and saved to spi_tiffs_final1/spi_201203.tif
# Shifted spi_201001.tif south by its length and saved to spi_tiffs_final1/spi_201001.tif
# Shifted spi_198303.tif south by its length and saved to spi_tiffs_final1/spi_198303.tif
# Shifted spi_199009.tif south by its length and saved to spi_tiffs_final1/spi_199009.tif
# Shifted spi_199008.tif south by its length and saved to spi_tiffs_final1/spi_199008.tif
# Shifted spi_198302.tif south by its length and saved to spi_tiffs_final1/spi_198302.tif
# Shifted spi_201202.tif south by its length and saved to spi_tiffs_final1/spi_201202.tif
# Shifted spi_200108.tif south by its length and saved to spi_tiffs_final1/spi_200108.tif
# Shifted spi_200901.tif south by its length and saved to spi_tiffs_final1/spi_200901.tif
# Shifted spi_198706.tif south by its length and saved to spi_tiffs_final1/spi_198706.tif
# Shifted spi_198712.tif south by its length and saved to spi_tiffs_final1/spi_198712.tif
# Shifted spi_201410.tif south by its length and saved to spi_tiffs_final1/spi_201410.tif
# Shifted spi_201404.tif south by its length and saved to spi_tiffs_final1/spi_201404.tif
# Shifted spi_198909.tif south by its length and saved to spi_tiffs_final1/spi_198909.tif
# Shifted spi_201809.tif south by its length and saved to spi_tiffs_final1/spi_201809.tif
# Shifted spi_198504.tif south by its length and saved to spi_tiffs_final1/spi_198504.tif
# Shifted spi_198510.tif south by its length and saved to spi_tiffs_final1/spi_198510.tif
# Shifted spi_201612.tif south by its length and saved to spi_tiffs_final1/spi_201612.tif
# Shifted spi_201606.tif south by its length and saved to spi_tiffs_final1/spi_201606.tif
# Shifted spi_199801.tif south by its length and saved to spi_tiffs_final1/spi_199801.tif
# Shifted spi_199803.tif south by its length and saved to spi_tiffs_final1/spi_199803.tif
# Shifted spi_201610.tif south by its length and saved to spi_tiffs_final1/spi_201610.tif
# Shifted spi_201604.tif south by its length and saved to spi_tiffs_final1/spi_201604.tif
# Shifted spi_198506.tif south by its length and saved to spi_tiffs_final1/spi_198506.tif
# Shifted spi_198512.tif south by its length and saved to spi_tiffs_final1/spi_198512.tif
# Shifted spi_201412.tif south by its length and saved to spi_tiffs_final1/spi_201412.tif
# Shifted spi_201406.tif south by its length and saved to spi_tiffs_final1/spi_201406.tif
# Shifted spi_198704.tif south by its length and saved to spi_tiffs_final1/spi_198704.tif
# Shifted spi_198710.tif south by its length and saved to spi_tiffs_final1/spi_198710.tif
# Shifted spi_200903.tif south by its length and saved to spi_tiffs_final1/spi_200903.tif
# Shifted spi_199208.tif south by its length and saved to spi_tiffs_final1/spi_199208.tif
# Shifted spi_201002.tif south by its length and saved to spi_tiffs_final1/spi_201002.tif
# Shifted spi_200308.tif south by its length and saved to spi_tiffs_final1/spi_200308.tif
# Shifted spi_198301.tif south by its length and saved to spi_tiffs_final1/spi_198301.tif
# Shifted spi_200309.tif south by its length and saved to spi_tiffs_final1/spi_200309.tif
# Shifted spi_201003.tif south by its length and saved to spi_tiffs_final1/spi_201003.tif
# Shifted spi_199209.tif south by its length and saved to spi_tiffs_final1/spi_199209.tif
# Shifted spi_201201.tif south by its length and saved to spi_tiffs_final1/spi_201201.tif
# Shifted spi_200902.tif south by its length and saved to spi_tiffs_final1/spi_200902.tif
# Shifted spi_198711.tif south by its length and saved to spi_tiffs_final1/spi_198711.tif
# Shifted spi_198705.tif south by its length and saved to spi_tiffs_final1/spi_198705.tif
# Shifted spi_201407.tif south by its length and saved to spi_tiffs_final1/spi_201407.tif
# Shifted spi_198507.tif south by its length and saved to spi_tiffs_final1/spi_198507.tif
# Shifted spi_201605.tif south by its length and saved to spi_tiffs_final1/spi_201605.tif
# Shifted spi_201611.tif south by its length and saved to spi_tiffs_final1/spi_201611.tif
# Shifted spi_199802.tif south by its length and saved to spi_tiffs_final1/spi_199802.tif
# Shifted spi_201601.tif south by its length and saved to spi_tiffs_final1/spi_201601.tif
# Shifted spi_199806.tif south by its length and saved to spi_tiffs_final1/spi_199806.tif
# Shifted spi_199812.tif south by its length and saved to spi_tiffs_final1/spi_199812.tif
# Shifted spi_198503.tif south by its length and saved to spi_tiffs_final1/spi_198503.tif
# Shifted spi_199609.tif south by its length and saved to spi_tiffs_final1/spi_199609.tif
# Shifted spi_200709.tif south by its length and saved to spi_tiffs_final1/spi_200709.tif
# Shifted spi_201403.tif south by its length and saved to spi_tiffs_final1/spi_201403.tif
# Shifted spi_200912.tif south by its length and saved to spi_tiffs_final1/spi_200912.tif
# Shifted spi_200906.tif south by its length and saved to spi_tiffs_final1/spi_200906.tif
# Shifted spi_198701.tif south by its length and saved to spi_tiffs_final1/spi_198701.tif
# Shifted spi_201205.tif south by its length and saved to spi_tiffs_final1/spi_201205.tif
# Shifted spi_201211.tif south by its length and saved to spi_tiffs_final1/spi_201211.tif
# Shifted spi_201007.tif south by its length and saved to spi_tiffs_final1/spi_201007.tif
# Shifted spi_198311.tif south by its length and saved to spi_tiffs_final1/spi_198311.tif
# Shifted spi_198305.tif south by its length and saved to spi_tiffs_final1/spi_198305.tif
# Shifted spi_198304.tif south by its length and saved to spi_tiffs_final1/spi_198304.tif
# Shifted spi_198310.tif south by its length and saved to spi_tiffs_final1/spi_198310.tif
# Shifted spi_201012.tif south by its length and saved to spi_tiffs_final1/spi_201012.tif
# Shifted spi_201006.tif south by its length and saved to spi_tiffs_final1/spi_201006.tif
# Shifted spi_201210.tif south by its length and saved to spi_tiffs_final1/spi_201210.tif
# Shifted spi_201204.tif south by its length and saved to spi_tiffs_final1/spi_201204.tif
# Shifted spi_200907.tif south by its length and saved to spi_tiffs_final1/spi_200907.tif
# Shifted spi_201402.tif south by its length and saved to spi_tiffs_final1/spi_201402.tif
# Shifted spi_200708.tif south by its length and saved to spi_tiffs_final1/spi_200708.tif
# Shifted spi_199608.tif south by its length and saved to spi_tiffs_final1/spi_199608.tif
# Shifted spi_198502.tif south by its length and saved to spi_tiffs_final1/spi_198502.tif
# Shifted spi_199807.tif south by its length and saved to spi_tiffs_final1/spi_199807.tif
# Shifted spi_201602.tif south by its length and saved to spi_tiffs_final1/spi_201602.tif
# Shifted spi_200508.tif south by its length and saved to spi_tiffs_final1/spi_200508.tif
# Shifted spi_199811.tif south by its length and saved to spi_tiffs_final1/spi_199811.tif
# Shifted spi_199805.tif south by its length and saved to spi_tiffs_final1/spi_199805.tif
# Shifted spi_202109.tif south by its length and saved to spi_tiffs_final1/spi_202109.tif
# Shifted spi_200905.tif south by its length and saved to spi_tiffs_final1/spi_200905.tif
# Shifted spi_200911.tif south by its length and saved to spi_tiffs_final1/spi_200911.tif
# Shifted spi_199408.tif south by its length and saved to spi_tiffs_final1/spi_199408.tif
# Shifted spi_198702.tif south by its length and saved to spi_tiffs_final1/spi_198702.tif
# Shifted spi_201212.tif south by its length and saved to spi_tiffs_final1/spi_201212.tif
# Shifted spi_201206.tif south by its length and saved to spi_tiffs_final1/spi_201206.tif
# Shifted spi_201010.tif south by its length and saved to spi_tiffs_final1/spi_201010.tif
# Shifted spi_201004.tif south by its length and saved to spi_tiffs_final1/spi_201004.tif
# Shifted spi_198306.tif south by its length and saved to spi_tiffs_final1/spi_198306.tif
# Shifted spi_198312.tif south by its length and saved to spi_tiffs_final1/spi_198312.tif
# Shifted spi_198307.tif south by its length and saved to spi_tiffs_final1/spi_198307.tif
# Shifted spi_201005.tif south by its length and saved to spi_tiffs_final1/spi_201005.tif
# Shifted spi_201011.tif south by its length and saved to spi_tiffs_final1/spi_201011.tif
# Shifted spi_201207.tif south by its length and saved to spi_tiffs_final1/spi_201207.tif
# Shifted spi_198703.tif south by its length and saved to spi_tiffs_final1/spi_198703.tif
# Shifted spi_199409.tif south by its length and saved to spi_tiffs_final1/spi_199409.tif
# Shifted spi_200910.tif south by its length and saved to spi_tiffs_final1/spi_200910.tif
# Shifted spi_200904.tif south by its length and saved to spi_tiffs_final1/spi_200904.tif
# Shifted spi_201401.tif south by its length and saved to spi_tiffs_final1/spi_201401.tif
# Shifted spi_202108.tif south by its length and saved to spi_tiffs_final1/spi_202108.tif
# Shifted spi_198501.tif south by its length and saved to spi_tiffs_final1/spi_198501.tif
# Shifted spi_199804.tif south by its length and saved to spi_tiffs_final1/spi_199804.tif
# Shifted spi_199810.tif south by its length and saved to spi_tiffs_final1/spi_199810.tif
# Shifted spi_200509.tif south by its length and saved to spi_tiffs_final1/spi_200509.tif
# Shifted spi_201603.tif south by its length and saved to spi_tiffs_final1/spi_201603.tif
